# %%
# !pip install -U transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 89.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 563.3/563.3 kB 24.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 43.6 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 70.0 MB/s eta 0:00:00:00:01
# ...
#   Attempting uninstall: hf-xet
#     Found existing installation: hf-xet 1.1.0
#     Uninstalling hf-xet-1.1.0:
#       Successfully uninstalled hf-xet-1.1.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.31.1
#     Uninstalling huggingface-hub-0.31.1:
#       Successfully uninstalled huggingface-hub-0.31.1
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.1
#     Uninstalling tokenizers-0.21.1:
#       Successfully uninstalled tokenizers-0.21.1
# ...

# %% [markdown]
# Model page: https://huggingface.co/klyang/MentaLLaMA-chat-7B
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/klyang/MentaLLaMA-chat-7B)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# Load the model and tokenizer
model_name = "tanusrich/Mental_Health_Chatbot"
model = AutoModelForCausalLM.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Move the model to the appropriate device (CPU or GPU)
device = torch.device("cpu")
model.to(device)

# Generate a response
def generate_response(user_input):
    inputs = tokenizer(user_input, return_tensors="pt").to(device)
    with torch.no_grad():
        output = model.generate(
            **inputs,
            max_new_tokens=200,
            temperature=0.7,
            top_k=50,
            top_p=0.9,
            repetition_penalty=1.2,
            pad_token_id=tokenizer.eos_token_id
        )
    response = tokenizer.decode(output[0], skip_special_tokens=True)
    return response

# Example interaction
user_input = "I'm feeling lonely and anxious. What can I do?"
response = generate_response(user_input)
print("Chatbot: ", response)
# Out:
# config.json:   0%|          | 0.00/712 [00:00<?, ?B/s]
# 2025-09-23 23:53:24.088138: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758671604.455204      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758671604.565439      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# ...

# %%
# Example interaction
user_input = "How can i overcome my loneliness?"
response = generate_response(user_input)
print("Chatbot: ", response)
# Out:
# Chatbot:  How can i overcome my loneliness? [/INST] Lonliness is a very real and painful experience for many people. It's important to recognize that you are not alone in this feeling, but it does take courage to reach out when we feel isolated or disconnected from others. One of the most important things you can do as someone who feels lonely is find supportive connections with other human beings-and I don’t just mean online relationships! Being connected to friends and family members is crucial because these individuals provide us with emotional validation and help remind us that our feelings are valid and normal. They also offer practical assistance if needed during difficult times (like job loss). Additionally, volunteering your time at local organizations might give back some sense purpose which could contribute towards overall wellbeing. Remember there are lots of resources available both within yourself & outside of them so don’t hesitate reaching out – even though its hard so
# ...
